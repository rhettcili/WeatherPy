# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import requests
import time 

from citipy import citipy

from datetime import datetime 

from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

coordinates = list(lat_lngs)

# %%
# for coordinate in coordinates:
#     print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
#           citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 739

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)


    city_url = url + "&q=" + city.replace(" ","+")


    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
        
    # print(requests.get(city_url).json())
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | esperance
# Processing Record 4 of Set 1 | port macquarie
# Processing Record 5 of Set 1 | klyuchi
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | dodge city
# Processing Record 8 of Set 1 | yinchuan
# Processing Record 9 of Set 1 | iqaluit
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | te anau
# Processing Record 13 of Set 1 | bemidji
# Processing Record 14 of Set 1 | kavieng
# Processing Record 15 of Set 1 | langxiang
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | buchanan
# Processing Record 19 of Set 1 | lavrentiya
# Processing Record 20 of Set 1 | asyut
# Processing Record 21 of Set 1 | pontes e lacerda
# Processing Record 22 of Set 1 | tasiilaq
# Processing Record 23 of Set 1 | broken hill
# Processing Record 24 of Set 1 | bengkulu
# Processing Record 25 of Set 1 | la ronge
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | ust-karsk
# Processing Record 28 of Set 1 | purpe
# Processing Record 29 of Set 1 | taltal
# Processing Record 30 of Set 1 | tanshui
# City not found. Skipping...
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | cedar city
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | ancud
# Processing Record 41 of Set 1 | portland
# Processing Record 42 of Set 1 | micheweni
# Processing Record 43 of Set 1 | san andres
# Processing Record 44 of Set 1 | hermosillo
# Processing Record 45 of Set 1 | braganca
# Processing Record 46 of Set 1 | alofi
# Processing Record 47 of Set 1 | pocone
# Processing Record 48 of Set 1 | byron bay
# Processing Record 49 of Set 1 | tres arroyos
# Processing Record 50 of Set 1 | torbay
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | cardston
# Processing Record 5 of Set 2 | hambantota
# Processing Record 6 of Set 2 | cordoba
# Processing Record 7 of Set 2 | rosarito
# Processing Record 8 of Set 2 | cherskiy
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | castro
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | taburao
# City not found. Skipping...
# Processing Record 13 of Set 2 | georgetown
# Processing Record 14 of Set 2 | novopavlovka
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | taganak
# Processing Record 17 of Set 2 | gladstone
# Processing Record 18 of Set 2 | leningradskiy
# Processing Record 19 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | china
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | trhove sviny
# Processing Record 23 of Set 2 | saint george
# Processing Record 24 of Set 2 | venado tuerto
# Processing Record 25 of Set 2 | lodja
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 2 | pevek
# Processing Record 29 of Set 2 | pindwara
# Processing Record 30 of Set 2 | prince rupert
# Processing Record 31 of Set 2 | xiaoweizhai
# Processing Record 32 of Set 2 | umm kaddadah
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | goundam
# Processing Record 35 of Set 2 | machico
# Processing Record 36 of Set 2 | levikha
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | kinarut
# Processing Record 39 of Set 2 | kavaratti
# Processing Record 40 of Set 2 | albany
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | waipawa
# Processing Record 44 of Set 2 | karistos
# City not found. Skipping...
# Processing Record 45 of Set 2 | lompoc
# Processing Record 46 of Set 2 | vila franca do campo
# Processing Record 47 of Set 2 | smithers
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | ankpa
# Processing Record 1 of Set 3 | haines junction
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | boa vista
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | palasa
# Processing Record 7 of Set 3 | isangel
# Processing Record 8 of Set 3 | seymchan
# Processing Record 9 of Set 3 | cape town
# Processing Record 10 of Set 3 | maizieres-les-metz
# Processing Record 11 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 3 | camacha
# Processing Record 13 of Set 3 | carnarvon
# Processing Record 14 of Set 3 | turochak
# Processing Record 15 of Set 3 | port hedland
# Processing Record 16 of Set 3 | hilo
# Processing Record 17 of Set 3 | nuevo progreso
# Processing Record 18 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | kaeo
# Processing Record 23 of Set 3 | kodiak
# Processing Record 24 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 3 | ponta do sol
# Processing Record 26 of Set 3 | palmer
# Processing Record 27 of Set 3 | verkhniy landekh
# Processing Record 28 of Set 3 | dukat
# Processing Record 29 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 3 | antibes
# Processing Record 31 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 3 | caluquembe
# Processing Record 34 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 3 | ostrovnoy
# Processing Record 36 of Set 3 | san patricio
# Processing Record 37 of Set 3 | campos gerais
# Processing Record 38 of Set 3 | labuhan
# Processing Record 39 of Set 3 | chimbote
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 3 | paamiut
# Processing Record 42 of Set 3 | arraial do cabo
# Processing Record 43 of Set 3 | basoko
# Processing Record 44 of Set 3 | inuvik
# Processing Record 45 of Set 3 | quatre cocos
# Processing Record 46 of Set 3 | kaitangata
# Processing Record 47 of Set 3 | coihaique
# Processing Record 48 of Set 3 | lagoa
# Processing Record 49 of Set 3 | ciudad bolivar
# Processing Record 50 of Set 3 | carutapera
# Processing Record 1 of Set 4 | bereda
# Processing Record 2 of Set 4 | okha
# Processing Record 3 of Set 4 | mayo
# Processing Record 4 of Set 4 | bihariganj
# Processing Record 5 of Set 4 | campbell river
# Processing Record 6 of Set 4 | geraldton
# Processing Record 7 of Set 4 | cervo
# Processing Record 8 of Set 4 | san quintin
# Processing Record 9 of Set 4 | yomitan
# City not found. Skipping...
# Processing Record 10 of Set 4 | eureka
# Processing Record 11 of Set 4 | cantaura
# Processing Record 12 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 13 of Set 4 | pangnirtung
# Processing Record 14 of Set 4 | mikhaylovka
# Processing Record 15 of Set 4 | ilulissat
# Processing Record 16 of Set 4 | hvolsvollur
# Processing Record 17 of Set 4 | charters towers
# Processing Record 18 of Set 4 | selje
# Processing Record 19 of Set 4 | havoysund
# Processing Record 20 of Set 4 | nome
# Processing Record 21 of Set 4 | antsohihy
# Processing Record 22 of Set 4 | drakino
# Processing Record 23 of Set 4 | ponta delgada
# Processing Record 24 of Set 4 | mahina
# Processing Record 25 of Set 4 | altamira
# Processing Record 26 of Set 4 | olga
# Processing Record 27 of Set 4 | saskylakh
# Processing Record 28 of Set 4 | dikson
# Processing Record 29 of Set 4 | madimba
# Processing Record 30 of Set 4 | cairns
# Processing Record 31 of Set 4 | tripoli
# Processing Record 32 of Set 4 | port alfred
# Processing Record 33 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 4 | bakchar
# Processing Record 35 of Set 4 | marawi
# Processing Record 36 of Set 4 | bethel
# Processing Record 37 of Set 4 | basco
# Processing Record 38 of Set 4 | moi
# Processing Record 39 of Set 4 | port hardy
# Processing Record 40 of Set 4 | virginia beach
# Processing Record 41 of Set 4 | katsuura
# Processing Record 42 of Set 4 | mantua
# Processing Record 43 of Set 4 | kanniyakumari
# Processing Record 44 of Set 4 | kysyl-syr
# Processing Record 45 of Set 4 | mitsamiouli
# Processing Record 46 of Set 4 | salalah
# Processing Record 47 of Set 4 | talnakh
# Processing Record 48 of Set 4 | putina
# Processing Record 49 of Set 4 | jejuri
# Processing Record 50 of Set 4 | dingle
# Processing Record 1 of Set 5 | markova
# Processing Record 2 of Set 5 | mount isa
# Processing Record 3 of Set 5 | opuwo
# Processing Record 4 of Set 5 | klaksvik
# Processing Record 5 of Set 5 | meulaboh
# Processing Record 6 of Set 5 | nicoya
# Processing Record 7 of Set 5 | lorengau
# Processing Record 8 of Set 5 | taormina
# Processing Record 9 of Set 5 | sidi ali
# Processing Record 10 of Set 5 | arcos de la frontera
# Processing Record 11 of Set 5 | nemuro
# Processing Record 12 of Set 5 | loukhi
# Processing Record 13 of Set 5 | naze
# Processing Record 14 of Set 5 | itapirapua
# Processing Record 15 of Set 5 | abalak
# Processing Record 16 of Set 5 | jieshi
# Processing Record 17 of Set 5 | solnechnyy
# Processing Record 18 of Set 5 | severo-kurilsk
# Processing Record 19 of Set 5 | rio tercero
# Processing Record 20 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 5 | general roca
# Processing Record 22 of Set 5 | partsa
# Processing Record 23 of Set 5 | serdobsk
# Processing Record 24 of Set 5 | ouro fino
# Processing Record 25 of Set 5 | cefalu
# Processing Record 26 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 5 | gornopravdinsk
# Processing Record 28 of Set 5 | porto empedocle
# Processing Record 29 of Set 5 | namatanai
# Processing Record 30 of Set 5 | saint-joseph
# Processing Record 31 of Set 5 | aswan
# Processing Record 32 of Set 5 | salme
# Processing Record 33 of Set 5 | birjand
# Processing Record 34 of Set 5 | beyneu
# Processing Record 35 of Set 5 | taoudenni
# Processing Record 36 of Set 5 | paucartambo
# City not found. Skipping...
# Processing Record 37 of Set 5 | thompson
# Processing Record 38 of Set 5 | rocha
# Processing Record 39 of Set 5 | lata
# Processing Record 40 of Set 5 | saldanha
# Processing Record 41 of Set 5 | codrington
# Processing Record 42 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 5 | rabak
# Processing Record 44 of Set 5 | necochea
# Processing Record 45 of Set 5 | mae hong son
# Processing Record 46 of Set 5 | atar
# Processing Record 47 of Set 5 | brae
# Processing Record 48 of Set 5 | cockburn town
# Processing Record 49 of Set 5 | agirish
# Processing Record 50 of Set 5 | belyy yar
# Processing Record 1 of Set 6 | olinda
# Processing Record 2 of Set 6 | bambous virieux
# Processing Record 3 of Set 6 | port blair
# Processing Record 4 of Set 6 | cabo san lucas
# Processing Record 5 of Set 6 | port lincoln
# Processing Record 6 of Set 6 | asau
# Processing Record 7 of Set 6 | pontian kecil
# Processing Record 8 of Set 6 | pisco
# Processing Record 9 of Set 6 | ust-nera
# Processing Record 10 of Set 6 | churapcha
# Processing Record 11 of Set 6 | teahupoo
# Processing Record 12 of Set 6 | ngunguru
# Processing Record 13 of Set 6 | sijunjung
# Processing Record 14 of Set 6 | whitianga
# Processing Record 15 of Set 6 | bandarbeyla
# Processing Record 16 of Set 6 | nambutalai
# Processing Record 17 of Set 6 | parksville
# Processing Record 18 of Set 6 | quzhou
# Processing Record 19 of Set 6 | verkhoyansk
# Processing Record 20 of Set 6 | cuamba
# Processing Record 21 of Set 6 | souillac
# Processing Record 22 of Set 6 | inirida
# Processing Record 23 of Set 6 | faanui
# Processing Record 24 of Set 6 | mahebourg
# Processing Record 25 of Set 6 | bathsheba
# Processing Record 26 of Set 6 | henties bay
# Processing Record 27 of Set 6 | merauke
# Processing Record 28 of Set 6 | kachkanar
# Processing Record 29 of Set 6 | oakdale
# Processing Record 30 of Set 6 | hasaki
# Processing Record 31 of Set 6 | kattivakkam
# Processing Record 32 of Set 6 | malakal
# Processing Record 33 of Set 6 | roald
# Processing Record 34 of Set 6 | sitka
# Processing Record 35 of Set 6 | dzerzhinskoye
# Processing Record 36 of Set 6 | okhotsk
# Processing Record 37 of Set 6 | uskedal
# City not found. Skipping...
# Processing Record 38 of Set 6 | hamilton
# Processing Record 39 of Set 6 | rock sound
# Processing Record 40 of Set 6 | airai
# Processing Record 41 of Set 6 | kirakira
# Processing Record 42 of Set 6 | san fernando
# Processing Record 43 of Set 6 | caravelas
# Processing Record 44 of Set 6 | road town
# Processing Record 45 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 6 | vila do maio
# Processing Record 47 of Set 6 | college
# Processing Record 48 of Set 6 | clyde river
# Processing Record 49 of Set 6 | los llanos de aridane
# Processing Record 50 of Set 6 | sao filipe
# Processing Record 1 of Set 7 | houma
# Processing Record 2 of Set 7 | santo domingo
# Processing Record 3 of Set 7 | bichura
# Processing Record 4 of Set 7 | ales
# Processing Record 5 of Set 7 | srikakulam
# Processing Record 6 of Set 7 | agadez
# Processing Record 7 of Set 7 | whitehorse
# Processing Record 8 of Set 7 | pendleton
# Processing Record 9 of Set 7 | vestmannaeyjar
# Processing Record 10 of Set 7 | shawinigan
# Processing Record 11 of Set 7 | adrar
# Processing Record 12 of Set 7 | tighina
# Processing Record 13 of Set 7 | nyurba
# Processing Record 14 of Set 7 | khatanga
# Processing Record 15 of Set 7 | victoria
# Processing Record 16 of Set 7 | vostok
# Processing Record 17 of Set 7 | bundaberg
# Processing Record 18 of Set 7 | tomatlan
# Processing Record 19 of Set 7 | post falls
# Processing Record 20 of Set 7 | gilazi
# City not found. Skipping...
# Processing Record 21 of Set 7 | fremont
# Processing Record 22 of Set 7 | biak
# Processing Record 23 of Set 7 | rio grande
# Processing Record 24 of Set 7 | orlik
# Processing Record 25 of Set 7 | pitimbu
# Processing Record 26 of Set 7 | tiznit
# Processing Record 27 of Set 7 | fujin
# Processing Record 28 of Set 7 | hazro
# Processing Record 29 of Set 7 | jinxiang
# Processing Record 30 of Set 7 | marienburg
# Processing Record 31 of Set 7 | vangaindrano
# Processing Record 32 of Set 7 | laguna
# Processing Record 33 of Set 7 | san ignacio
# Processing Record 34 of Set 7 | asfi
# Processing Record 35 of Set 7 | sorland
# Processing Record 36 of Set 7 | muswellbrook
# Processing Record 37 of Set 7 | misratah
# Processing Record 38 of Set 7 | boende
# Processing Record 39 of Set 7 | ahipara
# Processing Record 40 of Set 7 | chiredzi
# Processing Record 41 of Set 7 | tiksi
# Processing Record 42 of Set 7 | aginskoye
# Processing Record 43 of Set 7 | cayenne
# Processing Record 44 of Set 7 | alice springs
# Processing Record 45 of Set 7 | salta
# Processing Record 46 of Set 7 | long
# Processing Record 47 of Set 7 | hobyo
# Processing Record 48 of Set 7 | duku
# Processing Record 49 of Set 7 | borger
# Processing Record 50 of Set 7 | dawlatabad
# Processing Record 1 of Set 8 | nosy varika
# Processing Record 2 of Set 8 | slave lake
# Processing Record 3 of Set 8 | at-bashi
# Processing Record 4 of Set 8 | flinders
# Processing Record 5 of Set 8 | arlit
# Processing Record 6 of Set 8 | cidreira
# Processing Record 7 of Set 8 | san policarpo
# Processing Record 8 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 8 | maracacume
# Processing Record 10 of Set 8 | alliance
# Processing Record 11 of Set 8 | kerema
# Processing Record 12 of Set 8 | nizhnyaya omka
# Processing Record 13 of Set 8 | bilma
# Processing Record 14 of Set 8 | vao
# Processing Record 15 of Set 8 | kudahuvadhoo
# Processing Record 16 of Set 8 | zabid
# Processing Record 17 of Set 8 | pemba
# Processing Record 18 of Set 8 | mount gambier
# Processing Record 19 of Set 8 | jazzin
# City not found. Skipping...
# Processing Record 20 of Set 8 | bambanglipuro
# Processing Record 21 of Set 8 | mooi river
# City not found. Skipping...
# Processing Record 22 of Set 8 | magadan
# Processing Record 23 of Set 8 | hay river
# Processing Record 24 of Set 8 | nanortalik
# Processing Record 25 of Set 8 | grand gaube
# Processing Record 26 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 8 | sao joao da barra
# Processing Record 29 of Set 8 | la roche-sur-yon
# Processing Record 30 of Set 8 | hualmay
# Processing Record 31 of Set 8 | usulutan
# Processing Record 32 of Set 8 | yacopi
# Processing Record 33 of Set 8 | komsomolskiy
# Processing Record 34 of Set 8 | faya
# Processing Record 35 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 8 | plouzane
# Processing Record 37 of Set 8 | santa cruz de tenerife
# Processing Record 38 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 8 | areosa
# Processing Record 40 of Set 8 | zhigansk
# Processing Record 41 of Set 8 | berlevag
# Processing Record 42 of Set 8 | garh maharaja
# Processing Record 43 of Set 8 | llanes
# Processing Record 44 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 8 | karratha
# Processing Record 46 of Set 8 | kyra
# Processing Record 47 of Set 8 | stoughton
# Processing Record 48 of Set 8 | aras
# Processing Record 49 of Set 8 | haslett
# Processing Record 50 of Set 8 | hofn
# Processing Record 1 of Set 9 | wamba
# Processing Record 2 of Set 9 | barkly west
# Processing Record 3 of Set 9 | kerur
# Processing Record 4 of Set 9 | yulara
# Processing Record 5 of Set 9 | gobabis
# Processing Record 6 of Set 9 | drayton valley
# Processing Record 7 of Set 9 | normandin
# Processing Record 8 of Set 9 | tynda
# Processing Record 9 of Set 9 | noyabrsk
# Processing Record 10 of Set 9 | juifang
# City not found. Skipping...
# Processing Record 11 of Set 9 | tilichiki
# Processing Record 12 of Set 9 | petrila
# Processing Record 13 of Set 9 | halifax
# Processing Record 14 of Set 9 | deputatskiy
# Processing Record 15 of Set 9 | huanren
# Processing Record 16 of Set 9 | tabou
# Processing Record 17 of Set 9 | crestview
# Processing Record 18 of Set 9 | alyangula
# Processing Record 19 of Set 9 | provideniya
# Processing Record 20 of Set 9 | batagay-alyta
# Processing Record 21 of Set 9 | pinsk
# Processing Record 22 of Set 9 | cam ranh
# Processing Record 23 of Set 9 | tooele
# Processing Record 24 of Set 9 | jaciara
# Processing Record 25 of Set 9 | lakatoro
# Processing Record 26 of Set 9 | blackwater
# Processing Record 27 of Set 9 | lingao
# Processing Record 28 of Set 9 | shupiyan
# Processing Record 29 of Set 9 | taiyuan
# Processing Record 30 of Set 9 | kamenka
# Processing Record 31 of Set 9 | dunedin
# Processing Record 32 of Set 9 | imbituba
# Processing Record 33 of Set 9 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 34 of Set 9 | florianopolis
# Processing Record 35 of Set 9 | kruisfontein
# Processing Record 36 of Set 9 | batemans bay
# Processing Record 37 of Set 9 | xichang
# Processing Record 38 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 39 of Set 9 | po
# City not found. Skipping...
# Processing Record 40 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 41 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 9 | rodrigues alves
# Processing Record 43 of Set 9 | guerrero negro
# Processing Record 44 of Set 9 | mozarlandia
# Processing Record 45 of Set 9 | garowe
# Processing Record 46 of Set 9 | sao felix do xingu
# Processing Record 47 of Set 9 | altagracia de orituco
# Processing Record 48 of Set 9 | mwene-ditu
# Processing Record 49 of Set 9 | husavik
# Processing Record 50 of Set 9 | dauphin
# Processing Record 1 of Set 10 | khor
# Processing Record 2 of Set 10 | redmond
# Processing Record 3 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 10 | broome
# Processing Record 5 of Set 10 | saint-prosper
# Processing Record 6 of Set 10 | umm lajj
# Processing Record 7 of Set 10 | nenjiang
# Processing Record 8 of Set 10 | gwadar
# Processing Record 9 of Set 10 | talesh
# City not found. Skipping...
# Processing Record 10 of Set 10 | gigmoto
# Processing Record 11 of Set 10 | evensk
# Processing Record 12 of Set 10 | port-gentil
# Processing Record 13 of Set 10 | samarai
# Processing Record 14 of Set 10 | dong hoi
# Processing Record 15 of Set 10 | yumen
# Processing Record 16 of Set 10 | puerto escondido
# Processing Record 17 of Set 10 | varazze
# Processing Record 18 of Set 10 | conde
# Processing Record 19 of Set 10 | coahuayana
# Processing Record 20 of Set 10 | fortuna
# Processing Record 21 of Set 10 | margate
# Processing Record 22 of Set 10 | chase
# Processing Record 23 of Set 10 | milkovo
# Processing Record 24 of Set 10 | half moon bay
# Processing Record 25 of Set 10 | waddan
# Processing Record 26 of Set 10 | talcahuano
# Processing Record 27 of Set 10 | aksu
# Processing Record 28 of Set 10 | ortisoara
# Processing Record 29 of Set 10 | piacabucu
# Processing Record 30 of Set 10 | george
# Processing Record 31 of Set 10 | tucumcari
# Processing Record 32 of Set 10 | antsirabe
# Processing Record 33 of Set 10 | chuy
# Processing Record 34 of Set 10 | qiongshan
# Processing Record 35 of Set 10 | nioro
# Processing Record 36 of Set 10 | nalut
# Processing Record 37 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 38 of Set 10 | boden
# Processing Record 39 of Set 10 | kedougou
# Processing Record 40 of Set 10 | cacoal
# Processing Record 41 of Set 10 | port augusta
# Processing Record 42 of Set 10 | bubaque
# Processing Record 43 of Set 10 | hashtgerd
# Processing Record 44 of Set 10 | korla
# Processing Record 45 of Set 10 | porto walter
# Processing Record 46 of Set 10 | petrovskoye
# Processing Record 47 of Set 10 | everett
# Processing Record 48 of Set 10 | merced
# Processing Record 49 of Set 10 | vilhena
# Processing Record 50 of Set 10 | bam
# Processing Record 1 of Set 11 | makung
# City not found. Skipping...
# Processing Record 2 of Set 11 | ust-omchug
# Processing Record 3 of Set 11 | bilibino
# Processing Record 4 of Set 11 | baruun-urt
# Processing Record 5 of Set 11 | rawson
# Processing Record 6 of Set 11 | namibe
# Processing Record 7 of Set 11 | kahului
# Processing Record 8 of Set 11 | beringovskiy
# Processing Record 9 of Set 11 | tessalit
# Processing Record 10 of Set 11 | debre birhan
# Processing Record 11 of Set 11 | catio
# Processing Record 12 of Set 11 | porto seguro
# Processing Record 13 of Set 11 | lasa
# Processing Record 14 of Set 11 | aripuana
# Processing Record 15 of Set 11 | sabancuy
# Processing Record 16 of Set 11 | santa rosa
# Processing Record 17 of Set 11 | siocon
# Processing Record 18 of Set 11 | parana
# Processing Record 19 of Set 11 | saint-pierre
# Processing Record 20 of Set 11 | capreol
# Processing Record 21 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 11 | raga
# Processing Record 23 of Set 11 | nathdwara
# Processing Record 24 of Set 11 | belmopan
# Processing Record 25 of Set 11 | kiama
# Processing Record 26 of Set 11 | kollumerland
# City not found. Skipping...
# Processing Record 27 of Set 11 | tarko-sale
# Processing Record 28 of Set 11 | oranjemund
# Processing Record 29 of Set 11 | machiques
# Processing Record 30 of Set 11 | san matias
# Processing Record 31 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 33 of Set 11 | pochutla
# Processing Record 34 of Set 11 | la macarena
# Processing Record 35 of Set 11 | takoradi
# Processing Record 36 of Set 11 | ruteng
# Processing Record 37 of Set 11 | ust-kuyga
# Processing Record 38 of Set 11 | muros
# Processing Record 39 of Set 11 | shangrao
# Processing Record 40 of Set 11 | santiago del estero
# Processing Record 41 of Set 11 | jiayuguan
# Processing Record 42 of Set 11 | burica
# City not found. Skipping...
# Processing Record 43 of Set 11 | savannah bight
# Processing Record 44 of Set 11 | san angelo
# Processing Record 45 of Set 11 | mon
# Processing Record 46 of Set 11 | kutum
# Processing Record 47 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 11 | itarema
# Processing Record 49 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 50 of Set 11 | mikuni
# Processing Record 1 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 12 | wum
# Processing Record 3 of Set 12 | webuye
# Processing Record 4 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 5 of Set 12 | krasnoselkup
# Processing Record 6 of Set 12 | praia da vitoria
# Processing Record 7 of Set 12 | ascension
# Processing Record 8 of Set 12 | lithakia
# Processing Record 9 of Set 12 | mabay
# Processing Record 10 of Set 12 | cap malheureux
# Processing Record 11 of Set 12 | sulangan
# Processing Record 12 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 12 | bagan
# Processing Record 14 of Set 12 | darovskoy
# Processing Record 15 of Set 12 | mingshui
# Processing Record 16 of Set 12 | morgan city
# Processing Record 17 of Set 12 | moranbah
# Processing Record 18 of Set 12 | ulkan
# Processing Record 19 of Set 12 | salinas
# Processing Record 20 of Set 12 | rio gallegos
# Processing Record 21 of Set 12 | abu zabad
# Processing Record 22 of Set 12 | victor harbor
# Processing Record 23 of Set 12 | yerbogachen
# Processing Record 24 of Set 12 | hamada
# Processing Record 25 of Set 12 | ulladulla
# Processing Record 26 of Set 12 | skiros
# City not found. Skipping...
# Processing Record 27 of Set 12 | norman wells
# Processing Record 28 of Set 12 | mogadishu
# Processing Record 29 of Set 12 | lebork
# Processing Record 30 of Set 12 | hirara
# Processing Record 31 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 12 | erzin
# Processing Record 33 of Set 12 | oneonta
# Processing Record 34 of Set 12 | xining
# Processing Record 35 of Set 12 | tondano
# Processing Record 36 of Set 12 | tuatapere
# Processing Record 37 of Set 12 | maine-soroa
# Processing Record 38 of Set 12 | tunceli
# Processing Record 39 of Set 12 | maniitsoq
# Processing Record 40 of Set 12 | portoferraio
# Processing Record 41 of Set 12 | gomel
# Processing Record 42 of Set 12 | naifaru
# Processing Record 43 of Set 12 | baghdad
# Processing Record 44 of Set 12 | goba
# Processing Record 45 of Set 12 | lysyanka
# Processing Record 46 of Set 12 | canaries
# Processing Record 47 of Set 12 | alberton
# Processing Record 48 of Set 12 | vanimo
# Processing Record 49 of Set 12 | zemio
# Processing Record 50 of Set 12 | luderitz
# Processing Record 1 of Set 13 | jesi
# Processing Record 2 of Set 13 | grao mogol
# Processing Record 3 of Set 13 | tura
# Processing Record 4 of Set 13 | fairbanks
# Processing Record 5 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 6 of Set 13 | san cristobal
# Processing Record 7 of Set 13 | aleksandrovskiy zavod
# Processing Record 8 of Set 13 | kyrylivka
# Processing Record 9 of Set 13 | wawa
# Processing Record 10 of Set 13 | shellbrook
# Processing Record 11 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 13 | phrai bung
# City not found. Skipping...
# Processing Record 13 of Set 13 | saint-louis
# Processing Record 14 of Set 13 | glad
# Processing Record 15 of Set 13 | westport
# Processing Record 16 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 17 of Set 13 | bili oslavy
# Processing Record 18 of Set 13 | pravda
# Processing Record 19 of Set 13 | zhezkazgan
# Processing Record 20 of Set 13 | luganville
# Processing Record 21 of Set 13 | furth
# Processing Record 22 of Set 13 | maceio
# Processing Record 23 of Set 13 | winona
# Processing Record 24 of Set 13 | semey
# Processing Record 25 of Set 13 | popondetta
# Processing Record 26 of Set 13 | viedma
# Processing Record 27 of Set 13 | darnetal
# Processing Record 28 of Set 13 | grand-lahou
# Processing Record 29 of Set 13 | bahia de caraquez
# Processing Record 30 of Set 13 | boundiali
# Processing Record 31 of Set 13 | farah
# Processing Record 32 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 13 | toktogul
# Processing Record 34 of Set 13 | bowen
# Processing Record 35 of Set 13 | winnemucca
# Processing Record 36 of Set 13 | udachnyy
# Processing Record 37 of Set 13 | konstantinovka
# Processing Record 38 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 39 of Set 13 | ust-kulom
# Processing Record 40 of Set 13 | alto baudo
# City not found. Skipping...
# Processing Record 41 of Set 13 | arman
# Processing Record 42 of Set 13 | brasilia
# Processing Record 43 of Set 13 | zhuhai
# Processing Record 44 of Set 13 | kimbe
# Processing Record 45 of Set 13 | anrochte
# Processing Record 46 of Set 13 | novolvovsk
# City not found. Skipping...
# Processing Record 47 of Set 13 | bitung
# Processing Record 48 of Set 13 | kailua
# Processing Record 49 of Set 13 | calvinia
# Processing Record 50 of Set 13 | ayni
# Processing Record 1 of Set 14 | kiruna
# Processing Record 2 of Set 14 | yigou
# Processing Record 3 of Set 14 | stokmarknes
# Processing Record 4 of Set 14 | anchorage
# Processing Record 5 of Set 14 | morondava
# Processing Record 6 of Set 14 | gat
# Processing Record 7 of Set 14 | sola
# Processing Record 8 of Set 14 | beruni
# City not found. Skipping...
# Processing Record 9 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 10 of Set 14 | arrifes
# Processing Record 11 of Set 14 | manggar
# Processing Record 12 of Set 14 | yeppoon
# Processing Record 13 of Set 14 | san carlos de bariloche
# Processing Record 14 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 14 | yola
# Processing Record 16 of Set 14 | san jose
# Processing Record 17 of Set 14 | san
# Processing Record 18 of Set 14 | fortuna foothills
# Processing Record 19 of Set 14 | camana
# Processing Record 20 of Set 14 | bela vista
# Processing Record 21 of Set 14 | bridgetown
# Processing Record 22 of Set 14 | waingapu
# Processing Record 23 of Set 14 | skibbereen
# Processing Record 24 of Set 14 | narva-joesuu
# Processing Record 25 of Set 14 | abu samrah
# Processing Record 26 of Set 14 | awbari
# Processing Record 27 of Set 14 | taitung
# Processing Record 28 of Set 14 | doha
# Processing Record 29 of Set 14 | goderich
# Processing Record 30 of Set 14 | padang
# Processing Record 31 of Set 14 | shakhunya
# Processing Record 32 of Set 14 | lumphat
# Processing Record 33 of Set 14 | polson
# Processing Record 34 of Set 14 | sabang
# Processing Record 35 of Set 14 | jiazi
# Processing Record 36 of Set 14 | engels
# Processing Record 37 of Set 14 | loubomo
# Processing Record 38 of Set 14 | barillas
# Processing Record 39 of Set 14 | erenhot
# Processing Record 40 of Set 14 | buzmeyin
# Processing Record 41 of Set 14 | port pirie
# Processing Record 42 of Set 14 | ekibastuz
# Processing Record 43 of Set 14 | salinopolis
# Processing Record 44 of Set 14 | richards bay
# Processing Record 45 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 14 | presidencia roque saenz pena
# Processing Record 47 of Set 14 | egvekinot
# Processing Record 48 of Set 14 | acarau
# Processing Record 49 of Set 14 | touros
# Processing Record 50 of Set 14 | leshukonskoye
# Processing Record 1 of Set 15 | inhambane
# Processing Record 2 of Set 15 | lewiston
# Processing Record 3 of Set 15 | bosaso
# Processing Record 4 of Set 15 | sept-iles
# Processing Record 5 of Set 15 | homer
# Processing Record 6 of Set 15 | tutoia
# Processing Record 7 of Set 15 | esterhazy
# Processing Record 8 of Set 15 | waverly
# Processing Record 9 of Set 15 | ghatsila
# Processing Record 10 of Set 15 | chinhoyi
# Processing Record 11 of Set 15 | vagur
# Processing Record 12 of Set 15 | mbanza-ngungu
# Processing Record 13 of Set 15 | alghero
# Processing Record 14 of Set 15 | oum hadjer
# Processing Record 15 of Set 15 | araouane
# Processing Record 16 of Set 15 | davila
# Processing Record 17 of Set 15 | utevka
# Processing Record 18 of Set 15 | gejiu
# Processing Record 19 of Set 15 | antalaha
# Processing Record 20 of Set 15 | jiangyou
# Processing Record 21 of Set 15 | olafsvik
# Processing Record 22 of Set 15 | kesennuma
# City not found. Skipping...
# Processing Record 23 of Set 15 | kirkwall
# Processing Record 24 of Set 15 | noumea
# Processing Record 25 of Set 15 | calama
# Processing Record 26 of Set 15 | brownwood
# Processing Record 27 of Set 15 | sorong
# Processing Record 28 of Set 15 | acapulco
# Processing Record 29 of Set 15 | ko samui
# Processing Record 30 of Set 15 | kastamonu
# Processing Record 31 of Set 15 | bontang
# Processing Record 32 of Set 15 | puerto el triunfo
# Processing Record 33 of Set 15 | santa vitoria do palmar
# Processing Record 34 of Set 15 | sinazongwe
# Processing Record 35 of Set 15 | tawang
# Processing Record 36 of Set 15 | jelenia gora
# Processing Record 37 of Set 15 | narsaq
# Processing Record 38 of Set 15 | sikonge
# Processing Record 39 of Set 15 | pangody
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Puerto Ayora  -0.7393  -90.3518     69.55        95          58
# 1         Rikitea -23.1203 -134.9692     73.26        75           6
# 2       Esperance -33.8667  121.9000     63.90        73          93
# 3  Port Macquarie -31.4333  152.9167     63.90        44           9
# 4         Klyuchi  52.2667   79.1667     72.12        50          63
# 5       Hithadhoo  -0.6000   73.0833     81.88        73         100
# 6      Dodge City  37.7528 -100.0171     78.69        68          95
# 7        Yinchuan  38.4681  106.2731     84.81        29           1
# 8         Iqaluit  63.7506  -68.5145     49.73        71          75
# 9   Mar Del Plata -38.0023  -57.5575     48.22        94         100
#
#    Wind Speed Country                 Date Current Description
# 0        5.99      EC  2022-07-29 01:38:15       broken clouds
# 1       21.16      PF  2022-07-29 01:38:15          light rain
# 2       15.05      AU  2022-07-29 01:38:16          light rain
# 3       13.65      AU  2022-07-29 01:38:16           clear sky
# 4       11.95      RU  2022-07-29 01:38:16       broken clouds
# 5       13.44      MV  2022-07-29 01:38:17     overcast clouds
# 6        8.01      US  2022-07-29 01:38:17     overcast clouds
# 7        8.75      CN  2022-07-29 01:38:17           clear sky
# 8        2.30      CA  2022-07-29 01:38:18       broken clouds
# 9       13.80      AR  2022-07-29 01:38:18             drizzle

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Puerto Ayora      EC  -0.7393  -90.3518     69.55        95          58
# 1         Rikitea      PF -23.1203 -134.9692     73.26        75           6
# 2       Esperance      AU -33.8667  121.9000     63.90        73          93
# 3  Port Macquarie      AU -31.4333  152.9167     63.90        44           9
# 4         Klyuchi      RU  52.2667   79.1667     72.12        50          63
# 5       Hithadhoo      MV  -0.6000   73.0833     81.88        73         100
# 6      Dodge City      US  37.7528 -100.0171     78.69        68          95
# 7        Yinchuan      CN  38.4681  106.2731     84.81        29           1
# 8         Iqaluit      CA  63.7506  -68.5145     49.73        71          75
# 9   Mar Del Plata      AR -38.0023  -57.5575     48.22        94         100
#
#    Wind Speed Current Description                 Date
# 0        5.99       broken clouds  2022-07-29 01:38:15
# 1       21.16          light rain  2022-07-29 01:38:15
# 2       15.05          light rain  2022-07-29 01:38:16
# 3       13.65           clear sky  2022-07-29 01:38:16
# 4       11.95       broken clouds  2022-07-29 01:38:16
# 5       13.44     overcast clouds  2022-07-29 01:38:17
# 6        8.01     overcast clouds  2022-07-29 01:38:17
# 7        8.75           clear sky  2022-07-29 01:38:17
# 8        2.30       broken clouds  2022-07-29 01:38:18
# 9       13.80             drizzle  2022-07-29 01:38:18

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
